# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/IRIS (3).csv')

# %%
print("🔹 First 5 rows of dataset:")
print(df.head())
# Out:
# 🔹 First 5 rows of dataset:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
print("\n🔹 Dataset info:")
print(df.info())
# Out:
# 🔹 Dataset info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# None

# %%
print("\n🔹 Dataset description:")
print(df.describe())
# Out:
# 🔹 Dataset description:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
print("\n🔹 Missing values per column:")
print(df.isnull().sum())
# Out:
# 🔹 Missing values per column:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
if 'Species' in df.columns:
    sns.pairplot(df, hue='Species')
    plt.suptitle('Pairplot of Iris Features by Species', y=1.02)
    plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming df is already loaded
# df = pd.read_csv('/content/IRIS (3).csv')  # This line is commented out as df is already in the environment

plt.figure(figsize=(8, 6))

# Select only numeric columns for correlation calculation
numeric_df = df.select_dtypes(include=np.number)
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap of Features')
plt.show()

# %%
if 'Species' in df.columns:
    features = df.columns[df.columns != 'Species']
    for col in features:
        plt.figure(figsize=(8, 4))
        sns.boxplot(x='Species', y=col, data=df)
        plt.title(f'{col} distribution by Species')
        plt.show()

# %%
features = df.columns[df.columns != 'Species']
df[features].hist(figsize=(10, 8), bins=15, edgecolor='black')
plt.suptitle('Histogram of Features')
plt.show()

# %%
 if 'Species' in df.columns:
    for col in features:
        plt.figure(figsize=(8, 4))
        sns.violinplot(x='Species', y=col, data=df)
        plt.title(f'{col} violin plot by Species')
        plt.show()

# %%
if 'Species' in df.columns:
    for col in features:
        plt.figure(figsize=(8, 4))
        sns.violinplot(x='Species', y=col, data=df)
        plt.title(f'{col} violin plot by Species')
        plt.show()

# %%
if 'Species' not in df.columns:
    print("Warning: 'Species' column not found. Reloading the dataset.")
    try:
        df = pd.read_csv('/content/IRIS (3).csv')
    except FileNotFoundError:
        print("Error: Could not reload the dataset. Please check the file path.")
        # Skip the rest of the cell if data cannot be loaded
        exit()

# %%
df[features].hist(figsize=(10,8), bins=15, edgecolor='black')
plt.suptitle('Histograms of Features')
plt.show()

# %%
# Ensure the 'Species' column exists in the DataFrame before plotting

# Add the data loading step here to guarantee df is defined
import pandas as pd # Make sure pandas is imported

try:
    df = pd.read_csv('/content/IRIS (3).csv')
    print("Dataset loaded successfully.")
except FileNotFoundError:
    print("Error: Could not load the dataset. Please check the file path.")
    # If dataset cannot be loaded, print error and exit the cell execution
    exit() # Use exit() to stop execution of the current cell
except Exception as e:
    print(f"An unexpected error occurred during dataset loading: {e}")
    exit() # Use exit() for other errors as well


if 'Species' not in df.columns:
    print("Warning: 'Species' column not found for plotting even after attempting to reload dataset.")
    # If 'Species' is still missing, set features to an empty list
    features = []
    print("No features available for plotting violin plots.")
else:
    # If 'Species' is in df, define features
    features = df.columns[df.columns != 'Species']

    # Proceed with plotting only if there are features to plot
    if features:
        import matplotlib.pyplot as plt # Import matplotlib
        import seaborn as sns # Import seaborn

        for col in features:
            plt.figure(figsize=(8, 4))
            # Use the reloaded/verified df which should contain 'Species'
            sns.violinplot(x='Species', y=col, data=df)
            plt.title(f'{col} Violin Plot by Species')
            plt.show()
    else:
        print("No features available for plotting violin plots.")
# Out:
# Dataset loaded successfully.
# ...
# No features available for plotting violin plots.

# %%
for col in features:
    plt.figure(figsize=(8,4))
    sns.violinplot(x='Species', y=col, data=df)
    plt.title(f'Violin Plot of {col} by Species')
    plt.show()

# %%
# Ensure the 'Species' column exists in the DataFrame before plotting
if 'Species' not in df.columns:
    print("Warning: 'Species' column not found for plotting. Attempting to reload dataset.")
    try:
        # Reload the dataset to ensure 'Species' column is present
        df = pd.read_csv('/content/IRIS (3).csv')
        print("Dataset reloaded successfully before countplot.")
    except FileNotFoundError:
        print("Error: Could not reload the dataset for countplot. Please check the file path.")
        # If dataset cannot be loaded, print an error and skip the countplot
        # exit() is generally not recommended in notebooks; print and continue is better
        print("Skipping countplot due to missing 'Species' column.")
    except Exception as e:
        print(f"An error occurred while reloading the dataset for countplot: {e}")
        print("Skipping countplot due to error during dataset reload.")

# Proceed with plotting only if the 'Species' column is now present
if 'Species' in df.columns:
    sns.countplot(x='Species', data=df, palette='Set2')
    plt.title('Count of Each Species')
    plt.show()
else:
    print("Cannot plot countplot as 'Species' column is still missing.")
# Out:
# ...
# Dataset reloaded successfully before countplot.
# Cannot plot countplot as 'Species' column is still missing.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Explicitly load the dataset to ensure df and 'Species' column are available
try:
    df = pd.read_csv('/content/IRIS (3).csv')
    print("Dataset loaded successfully.")
except FileNotFoundError:
    print("Error: Could not load the dataset. Please check the file path.")
    df = None  # Set df to None to prevent further errors if loading failed
except Exception as e:
    print(f"An error occurred while loading the dataset: {e}")
    df = None  # Set df to None in case of other errors

# Proceed with plotting only if the DataFrame was loaded and 'Species' column exists
if df is not None and 'Species' in df.columns:
    # Ensure 'PetalArea' column exists as well
    if 'PetalArea' in df.columns:
        sns.boxplot(x='Species', y='PetalArea', data=df)
        plt.title('Petal Area by Species')
        plt.show()
    else:
        print("Error: 'PetalArea' column not found in the dataset.")
else:
    print("Cannot plot boxplot as dataset was not loaded or 'Species' column is missing.")
# Out:
# Dataset loaded successfully.
# Cannot plot boxplot as dataset was not loaded or 'Species' column is missing.

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2728e1d7-203a-4b9b-8655-55fcbe2d4012" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2728e1d7-203a-4b9b-8655-55fcbe2d4012">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
print(df.head())
print(df.info())
print(df.describe())
print(df.isnull().sum())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# None
#        sepal_length  sepal_width  petal_length  petal_width
# ...

# %%
num_df = df.select_dtypes(include='number')

# %%
from google.colab import files
uploaded = files.upload()

# Reload the dataset after files.upload() to ensure df is a DataFrame
import pandas as pd  # Ensure pandas is imported if not already in the environment

try:
    df = pd.read_csv('/content/IRIS (3).csv')
    print("Dataset reloaded successfully.")
except FileNotFoundError:
    print("Error: Could not reload the dataset after upload. Please check the file path.")
except Exception as e:
    print(f"An error occurred while reloading the dataset: {e}")
# Out:
#      <input type="file" id="files-1f070c4d-129d-45d1-9b4b-f0c71678b0fc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1f070c4d-129d-45d1-9b4b-f0c71678b0fc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
sns.heatmap(num_df.corr(), annot=True, cmap='coolwarm')
plt.show()

# %%
# Ensure the 'Species' column exists in the DataFrame before plotting
if 'Species' in df.columns and df is not None:  # Check if df is not None and 'Species' exists
    # Select only numeric columns for plotting
    numeric_cols = df.select_dtypes(include=np.number).columns

    if len(numeric_cols) > 0:  # Check if there are numeric columns to plot
        for col in numeric_cols:
            plt.figure(figsize=(8, 4))
            # Use the full df which contains the 'Species' column for the x-axis
            sns.boxplot(x='Species', y=col, data=df)
            plt.title(f'{col} by Species')
            plt.show()
    else:
        print("No numeric columns found in the dataset to plot boxplots.")
else:  # This 'else' is paired with the initial 'if'
    print("Cannot plot boxplots as dataset was not loaded or 'Species' column is missing.")

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Explicitly load the dataset to ensure df and 'Species' column are available
# This ensures df is a valid DataFrame with the 'Species' column before plotting
try:
    df = pd.read_csv('/content/IRIS (3).csv')
    print("Dataset loaded successfully for countplot.")
except FileNotFoundError:
    print("Error: Could not load the dataset for countplot. Please check the file path.")
    # If dataset cannot be loaded, exit or handle the error appropriately
    # For a notebook, printing an error and returning is usually sufficient.
    # Raising an error would also stop execution.
    raise FileNotFoundError("Cannot proceed without the dataset.")
except Exception as e:
    print(f"An error occurred while loading the dataset for countplot: {e}")
    raise RuntimeError("An error occurred during dataset loading.")  # Re-raise the exception

# Ensure the 'Species' column exists in the DataFrame before plotting
if 'Species' in df.columns:
    sns.countplot(x='Species', data=df)
    plt.title('Count of Each Species')
    plt.show()
else:
    # This case should ideally not be hit if the file is loaded correctly
    # but included as a safeguard.
    print("Error: 'Species' column not found in the dataset after loading.")
# Out:
# Dataset loaded successfully for countplot.
# Error: 'Species' column not found in the dataset after loading.
